# %% [markdown]
# Write a program to download the data from the link given below and then read the data and convert the into the proper structure and return it as a CSV file.
#
# Link - https://data.nasa.gov/resource/y77d-th95.json
#
# Note - Write code comments wherever needed for code understanding.
#
# Excepted Output Data Attributes
# - Name of Earth Meteorite - string
# - id - ID of Earth Meteorite - int
# - nametype - string
# - recclass - string
# - mass - Mass of Earth Meteorite - float
# - year - Year at which Earth Meteorite was hit - datetime format
# - reclat - float
# - reclong - float
# - point coordinates - list of int

# %%
import requests as req
import pandas as pd
from datetime import datetime

url = "https://data.nasa.gov/resource/y77d-th95.json"

resp = req.get(url)

json_data = resp.json() # Download data in the form of json

# %%
# Create lists to store the extracted attributes
name = []
ids = []
nametype = []
recclass = []
mass = []
year = []
reclat = []
reclong = []
point_coordinates = []

# %%
# Iterate over data in the 'meteorite' list
for data in data_json:
    name.append(data.get('name'))
    ids.append(data.get('id'))
    nametype.append(data.get('nametype'))
    recclass.append(data.get('recclass'))

    # Handle the 'mass' field
    mass_value = data.get('mass')
    if mass_value and mass_value.isdigit():
        mass.append(int(mass_value))
    else:
        mass.append(None)

    if data.get('year'):
        try:
            year.append(parser.parse(data['year']))
        except ValueError:
            year.append(None)
    else:
        year.append(None)

    reclat.append(data.get('reclat'))
    reclong.append(data.get('reclong'))

# %%
# Create a DataFrame from the extracted attributes
df = pd.DataFrame({
    "name": name,
    "id": ids,
    "nametype": nametype,
    "recclass": recclass,
    "mass": mass,
    "year": year,
    "reclat": reclat,
    "reclong": reclong
})

# %%
df.head()
# Out:
#        name   id nametype     recclass      mass                 year
# 0    Aachen    1    Valid           L5      21.0  1880-01-01 00:00:00  \
# 1    Aarhus    2    Valid           H6     720.0  1951-01-01 00:00:00
# 2      Abee    6    Valid          EH4  107000.0  1952-01-01 00:00:00
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  1976-01-01 00:00:00
# 4   Achiras  370    Valid           L6     780.0  1902-01-01 00:00:00
#
#        reclat      reclong
# 0   50.775000     6.083330
# 1   56.183330    10.233330
# 2   54.216670  -113.000000
# 3   16.883330   -99.900000
# 4  -33.166670   -64.950000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      1000 non-null   object
#  1   id        1000 non-null   object
#  2   nametype  1000 non-null   object
#  3   recclass  1000 non-null   object
#  4   mass      899 non-null    float64
#  5   year      999 non-null    object
#  6   reclat    988 non-null    object
#  7   reclong   988 non-null    object
# dtypes: float64(1), object(7)
# memory usage: 62.6+ KB

# %%
df['name'] = df['name'].astype(str)
df['id'] = df['id'].astype(int)
df['nametype'] = df['nametype'].astype(str)
df['mass'] = df['mass'].astype(float)
df['recclass'] = df['recclass'].astype(str)
df['reclat'] = df['reclat'].astype(float)
df['reclong'] = df['reclong'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      1000 non-null   object
#  1   id        1000 non-null   int32
#  2   nametype  1000 non-null   object
#  3   recclass  1000 non-null   object
#  4   mass      899 non-null    float64
#  5   year      999 non-null    object
#  6   reclat    988 non-null    float64
#  7   reclong   988 non-null    float64
# dtypes: float64(3), int32(1), object(4)
# memory usage: 58.7+ KB

# %%
df['point_coordinates'] = df.apply(lambda row: [row['reclat'], row['reclong']], axis=1)

# %%
df['year'] = pd.to_datetime(df['year'], errors='coerce')

# %%
df['year'] = pd.to_datetime(df['year'], format='%Y-%m-%d')

# %%
df['year'].isnull().sum()
# Out:
# 17

# %%
df = df.dropna(subset=['year'])

# %%
df.to_csv("ex.csv", index=False)

# %%
df['year_only'] = data['year'].dt.year
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[199], line 1
# ----> 1 df['year_only'] = data['year'].dt.year
#
# AttributeError: 'str' object has no attribute 'dt'

# %%
df
# Out:
#           name     id nametype               recclass      mass       year
# 0       Aachen      1    Valid                     L5      21.0 1880-01-01  \
# 1       Aarhus      2    Valid                     H6     720.0 1951-01-01
# 2         Abee      6    Valid                    EH4  107000.0 1952-01-01
# 3     Acapulco     10    Valid            Acapulcoite    1914.0 1976-01-01
# 4      Achiras    370    Valid                     L6     780.0 1902-01-01
# ..         ...    ...      ...                    ...       ...        ...
# 995   Tirupati  24009    Valid                     H6     230.0 1934-01-01
# 996    Tissint  54823    Valid  Martian (shergottite)    7000.0 2011-01-01
# 997      Tjabe  24011    Valid                     H6   20000.0 1869-01-01
# 998   Tjerebon  24012    Valid                     L5   16500.0 1922-01-01
# 999  Tomakovka  24019    Valid                    LL6     600.0 1905-01-01
#
#        reclat    reclong      point_coordinates
# ...

# %%
# Out:
# 1

# %%
df['year_only'] = data['year'].dt.year
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[140], line 1
# ----> 1 df['year_only'] = data['year'].dt.year
#
# AttributeError: 'str' object has no attribute 'dt'

# %%
df['year'] = df['year'].astype(str)
# Out:
# C:\Users\Jecky\AppData\Local\Temp\ipykernel_6900\573773785.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = df['year'].astype(str)

# %%
df['year'] = df['year'].str.replace('T', ' ')
# Out:
# C:\Users\Jecky\AppData\Local\Temp\ipykernel_6900\365416961.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = df['year'].str.replace('T', ' ')

# %%
df.head()
# Out:
#        name   id nametype     recclass      mass                 year
# 0    Aachen    1    Valid           L5      21.0  1880-01-01 00:00:00  \
# 1    Aarhus    2    Valid           H6     720.0  1951-01-01 00:00:00
# 2      Abee    6    Valid          EH4  107000.0  1952-01-01 00:00:00
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  1976-01-01 00:00:00
# 4   Achiras  370    Valid           L6     780.0  1902-01-01 00:00:00
#
#      reclat    reclong     point_coordinates
# 0  50.77500    6.08333     [50.775, 6.08333]
# 1  56.18333   10.23333  [56.18333, 10.23333]
# 2  54.21667 -113.00000    [54.21667, -113.0]
# 3  16.88333  -99.90000     [16.88333, -99.9]
# 4 -33.16667  -64.95000   [-33.16667, -64.95]

# %%
df['year'] = pd.to_datetime(df['year'], errors='coerce')

# %%
df['year_only'] = data['year'].dt.year
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[128], line 1
# ----> 1 df['year_only'] = data['year'].dt.year
#
# AttributeError: 'str' object has no attribute 'dt'

# %%
df[['date','time']] = df['year'].str.split(' ')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[126], line 1
# ----> 1 df[['date','time']] = df['year'].str.split(' ')
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:3947, in DataFrame.__setitem__(self, key, value)
#    3945     self._setitem_frame(key, value)
#    3946 elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3947     self._setitem_array(key, value)
#    3948 elif isinstance(value, DataFrame):
#    3949     self._set_item_frame_value(key, value)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:4006, in DataFrame._setitem_array(self, key, value)
#    4003     return self._setitem_array(key, value)
#    4005 else:
# -> 4006     self._iset_not_inplace(key, value)
#
# ...

# %%
df.head(175)
# Out:
#                   name    id nametype     recclass      mass
# 0               Aachen     1    Valid           L5      21.0  \
# 1               Aarhus     2    Valid           H6     720.0
# 2                 Abee     6    Valid          EH4  107000.0
# 3             Acapulco    10    Valid  Acapulcoite    1914.0
# 4              Achiras   370    Valid           L6     780.0
# ..                 ...   ...      ...          ...       ...
# 170           Caratash  5265    Valid          LL6       8.0
# 171           Castalia  5291    Valid           H5    7300.0
# 172  Castel Berardenga  5292    Valid   Stone-uncl       0.0
# 173            Castine  5293    Valid           L6      94.0
# 174      Castrovillari  5295    Valid   Stone-uncl   15000.0
#
#                         year    reclat    reclong
# 0    1880-01-01 00:00:00.000  50.77500    6.08333
# 1    1951-01-01 00:00:00.000  56.18333   10.23333
# 2    1952-01-01 00:00:00.000  54.21667 -113.00000
# ...
